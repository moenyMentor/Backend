# %%
# !pip install "langchain==0.2.6"
# !pip install "ibm-watsonx-ai==1.0.10"
# !pip install "langchain_ibm==0.1.8"
# !pip install "langchain_community==0.2.6"
# !pip install "sentence-transformers==3.0.1"
# !pip install "chromadb==0.5.3"
# !pip install "pydantic==2.8.2"
# !pip install "langchain-huggingface==0.0.3"
# !pip install "python-dotenv==1.0.1"
# Out:
# Collecting langchain==0.2.6
#   Using cached langchain-0.2.6-py3-none-any.whl (975 kB)
# Collecting numpy<2,>=1
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0
#   Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting langchain-core<0.3.0,>=0.2.10
#   Downloading langchain_core-0.2.37-py3-none-any.whl (396 kB)
#      ---------------------------------------- 0.0/396.2 kB ? eta -:--:--
#      -------- ------------------------------ 81.9/396.2 kB 4.5 MB/s eta 0:00:01
#      ----------------- -------------------- 184.3/396.2 kB 2.2 MB/s eta 0:00:01
#      ---------------------------- --------- 297.0/396.2 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------  389.1/396.2 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 396.2/396.2 kB 1.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0.0,>=4.0.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting PyYAML>=5.3
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Using cached aiohttp-3.10.5-cp310-cp310-win_amd64.whl (379 kB)
# Collecting pydantic<3,>=1
#   Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.108-py3-none-any.whl (150 kB)
#      ---------------------------------------- 0.0/150.7 kB ? eta -:--:--
#      ------------------------------------ - 143.4/150.7 kB 8.3 MB/s eta 0:00:01
#      -------------------------------------- 150.7/150.7 kB 3.0 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting SQLAlchemy<3,>=1.4
#   Using cached SQLAlchemy-2.0.32-cp310-cp310-win_amd64.whl (2.1 MB)
# Collecting requests<3,>=2
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.6-cp310-cp310-win_amd64.whl (78 kB)
#      ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#      ---------------------------------------- 78.8/78.8 kB ? eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Using cached aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (24.1)
# Collecting jsonpatch<2.0,>=1.33
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (4.12.2)
# Collecting httpx<1,>=0.23.0
#   Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Collecting orjson<4.0.0,>=3.9.14
#   Using cached orjson-3.10.7-cp310-none-win_amd64.whl (137 kB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.20.1
#   Using cached pydantic_core-2.20.1-cp310-none-win_amd64.whl (1.9 MB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.8-py3-none-any.whl (66 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      ---------------------------------------- 0.0/167.3 kB ? eta -:--:--
#      -------------------------------------- 167.3/167.3 kB 9.8 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Using cached greenlet-3.0.3-cp310-cp310-win_amd64.whl (292 kB)
# Collecting anyio
#   Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.2.2)
# Installing collected packages: urllib3, tenacity, sniffio, PyYAML, pydantic-core, orjson, numpy, multidict, jsonpointer, idna, h11, greenlet, frozenlist, charset-normalizer, certifi, attrs, async-timeout, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests, pydantic, jsonpatch, httpcore, anyio, aiosignal, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.32 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 async-timeout-4.0.3 attrs-24.2.0 certifi-2024.8.30 charset-normalizer-3.3.2 frozenlist-1.4.1 greenlet-3.0.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 idna-3.8 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.6 langchain-core-0.2.37 langchain-text-splitters-0.2.2 langsmith-0.1.108 multidict-6.0.5 numpy-1.26.4 orjson-3.10.7 pydantic-2.8.2 pydantic-core-2.20.1 requests-2.32.3 sniffio-1.3.1 tenacity-8.5.0 urllib3-2.2.2 yarl-1.9.6
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ibm-watsonx-ai==1.0.10
#   Using cached ibm_watsonx_ai-1.0.10-py3-none-any.whl (936 kB)
# Requirement already satisfied: packaging in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai==1.0.10) (24.1)
# Collecting lomond
#   Using cached lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Collecting importlib-metadata
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: urllib3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2.2.2)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: certifi in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2024.8.30)
# Collecting ibm-cos-sdk<2.14.0,>=2.12.0
#   Using cached ibm-cos-sdk-2.13.6.tar.gz (58 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2.32.3)
# Collecting pandas<2.2.0,>=0.24.2
#   Using cached pandas-2.1.4-cp310-cp310-win_amd64.whl (10.7 MB)
# Collecting ibm-cos-sdk-core==2.13.6
#   Using cached ibm-cos-sdk-core-2.13.6.tar.gz (1.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ibm-cos-sdk-s3transfer==2.13.6
#   Using cached ibm-cos-sdk-s3transfer-2.13.6.tar.gz (139 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jmespath<=1.0.1,>=0.10.0
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (2.9.0.post0)
# Collecting requests
#   Using cached requests-2.32.2-py3-none-any.whl (63 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.3.2)
# Collecting zipp>=0.5
#   Using cached zipp-3.20.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from lomond->ibm-watsonx-ai==1.0.10) (1.16.0)
# Installing collected packages: pytz, zipp, tzdata, tabulate, requests, lomond, jmespath, pandas, importlib-metadata, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Running setup.py install for ibm-cos-sdk-core: started
#   Running setup.py install for ibm-cos-sdk-core: finished with status 'done'
#   Running setup.py install for ibm-cos-sdk-s3transfer: started
#   Running setup.py install for ibm-cos-sdk-s3transfer: finished with status 'done'
#   Running setup.py install for ibm-cos-sdk: started
#   Running setup.py install for ibm-cos-sdk: finished with status 'done'
# Successfully installed ibm-cos-sdk-2.13.6 ibm-cos-sdk-core-2.13.6 ibm-cos-sdk-s3transfer-2.13.6 ibm-watsonx-ai-1.0.10 importlib-metadata-8.4.0 jmespath-1.0.1 lomond-0.3.3 pandas-2.1.4 pytz-2024.1 requests-2.32.2 tabulate-0.9.0 tzdata-2024.1 zipp-3.20.1
#   DEPRECATION: ibm-cos-sdk-core is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: ibm-cos-sdk-s3transfer is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: ibm-cos-sdk is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain_ibm==0.1.8
#   Using cached langchain_ibm-0.1.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_ibm==0.1.8) (0.2.37)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.0.8 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_ibm==0.1.8) (1.0.10)
# Requirement already satisfied: lomond in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (0.3.3)
# Requirement already satisfied: requests in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.32.2)
# Requirement already satisfied: tabulate in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (0.9.0)
# Requirement already satisfied: urllib3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.2.2)
# Requirement already satisfied: importlib-metadata in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (8.4.0)
# Requirement already satisfied: packaging in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (24.1)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.1.4)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: certifi in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2024.8.30)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.1.108)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (8.5.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (4.12.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (3.10.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.27.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2024.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.20.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.16.0)
# Requirement already satisfied: anyio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (4.4.0)
# Requirement already satisfied: sniffio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.2.2)
# Installing collected packages: langchain_ibm
# Successfully installed langchain_ibm-0.1.8
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain_community==0.2.6
#   Using cached langchain_community-0.2.6-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (3.10.5)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (0.1.108)
# Requirement already satisfied: requests<3,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (2.32.2)
# Requirement already satisfied: langchain<0.3.0,>=0.2.6 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (0.2.6)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (6.0.2)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (0.2.37)
# Requirement already satisfied: numpy<2,>=1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (1.26.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (2.0.32)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain_community==0.2.6) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (2.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.9.6)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (2.8.2)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (0.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (3.10.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (0.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests<3,>=2->langchain_community==0.2.6) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests<3,>=2->langchain_community==0.2.6) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests<3,>=2->langchain_community==0.2.6) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests<3,>=2->langchain_community==0.2.6) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.2.6) (3.0.3)
# Requirement already satisfied: httpcore==1.* in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.3.1)
# Requirement already satisfied: anyio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (4.4.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (2.20.1)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.2.2)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain_community-0.2.6 marshmallow-3.22.0 mypy-extensions-1.0.0 typing-inspect-0.9.0
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting sentence-transformers==3.0.1
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Collecting tqdm
#   Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.1-cp310-cp310-win_amd64.whl (11.0 MB)
# Collecting huggingface-hub>=0.15.1
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Collecting Pillow
#   Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Collecting transformers<5.0.0,>=4.34.0
#   Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# Collecting scipy
#   Using cached scipy-1.14.1-cp310-cp310-win_amd64.whl (44.8 MB)
# Collecting torch>=1.11.0
#   Using cached torch-2.4.0-cp310-cp310-win_amd64.whl (197.9 MB)
# Requirement already satisfied: numpy in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers==3.0.1) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (6.0.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (24.1)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (4.12.2)
# Collecting filelock
#   Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.32.2)
# Collecting sympy
#   Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Collecting networkx
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: colorama in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from tqdm->sentence-transformers==3.0.1) (0.4.6)
# Collecting tokenizers<0.20,>=0.19
#   Using cached tokenizers-0.19.1-cp310-none-win_amd64.whl (2.2 MB)
# Collecting safetensors>=0.4.1
#   Using cached safetensors-0.4.4-cp310-none-win_amd64.whl (285 kB)
# Collecting regex!=2019.12.17
#   Using cached regex-2024.7.24-cp310-cp310-win_amd64.whl (269 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.2.2)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, tqdm, threadpoolctl, sympy, scipy, safetensors, regex, Pillow, networkx, MarkupSafe, joblib, fsspec, filelock, scikit-learn, jinja2, huggingface-hub, torch, tokenizers, transformers, sentence-transformers
# Successfully installed MarkupSafe-2.1.5 Pillow-10.4.0 filelock-3.15.4 fsspec-2024.6.1 huggingface-hub-0.24.6 jinja2-3.1.4 joblib-1.4.2 mpmath-1.3.0 networkx-3.3 regex-2024.7.24 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.1 sentence-transformers-3.0.1 sympy-1.13.2 threadpoolctl-3.5.0 tokenizers-0.19.1 torch-2.4.0 tqdm-4.66.5 transformers-4.44.2
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting chromadb==0.5.3
#   Using cached chromadb-0.5.3-py3-none-any.whl (559 kB)
# Collecting uvicorn[standard]>=0.18.3
#   Using cached uvicorn-0.30.6-py3-none-any.whl (62 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.6.0-py2.py3-none-any.whl (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      ---------------------------------------- 50.6/50.6 kB 2.5 MB/s eta 0:00:00
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#      ---------------------------------------- 0.0/110.5 kB ? eta -:--:--
#      -------------------------------------- 110.5/110.5 kB 6.3 MB/s eta 0:00:00
# Collecting overrides>=7.3.1
#   Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (4.66.5)
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.66.1-cp310-cp310-win_amd64.whl (4.3 MB)
#      ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/4.3 MB 9.6 MB/s eta 0:00:01
#      ------ --------------------------------- 0.7/4.3 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.3/4.3 MB 10.2 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.8/4.3 MB 10.4 MB/s eta 0:00:01
#      ------------------- -------------------- 2.1/4.3 MB 10.2 MB/s eta 0:00:01
#      -------------------------- ------------- 2.8/4.3 MB 10.6 MB/s eta 0:00:01
#      ------------------------------- -------- 3.3/4.3 MB 10.6 MB/s eta 0:00:01
#      ------------------------------------ --- 3.9/4.3 MB 10.8 MB/s eta 0:00:01
#      -------------------------------------- - 4.2/4.3 MB 10.3 MB/s eta 0:00:01
#      ---------------------------------------  4.3/4.3 MB 10.5 MB/s eta 0:00:01
#      ---------------------------------------- 4.3/4.3 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (4.12.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (8.5.0)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 0.0/64.0 kB ? eta -:--:--
#      ---------------------------------------- 64.0/64.0 kB 1.7 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1
#   Using cached onnxruntime-1.19.0-cp310-cp310-win_amd64.whl (11.1 MB)
# Requirement already satisfied: requests>=2.28 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (2.32.2)
# Collecting importlib-resources
#   Using cached importlib_resources-6.4.4-py3-none-any.whl (35 kB)
# Collecting pypika>=0.48.9
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Collecting bcrypt>=4.0.1
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (0.19.1)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (6.0.2)
# Collecting fastapi>=0.95.2
#   Using cached fastapi-0.112.2-py3-none-any.whl (93 kB)
# Collecting kubernetes>=28.1.0
#   Using cached kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
# Collecting build>=1.0.3
#   Using cached build-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (3.10.7)
# Collecting mmh3>=4.0.1
#   Using cached mmh3-4.1.0-cp310-cp310-win_amd64.whl (31 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (2.8.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (0.27.2)
# Collecting typer>=0.9.0
#   Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from chromadb==0.5.3) (1.26.4)
# Collecting chroma-hnswlib==0.7.3
#   Using cached chroma_hnswlib-0.7.3-cp310-cp310-win_amd64.whl (150 kB)
# Requirement already satisfied: packaging>=19.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from build>=1.0.3->chromadb==0.5.3) (24.1)
# Collecting tomli>=1.1.0
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting pyproject_hooks
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: colorama in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from build>=1.0.3->chromadb==0.5.3) (0.4.6)
# Collecting starlette<0.39.0,>=0.37.2
#   Downloading starlette-0.38.4-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.4 kB ? eta -:--:--
#      ---------------------------------------- 71.4/71.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: httpcore==1.* in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.3.1)
# Requirement already satisfied: certifi in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx>=0.27.0->chromadb==0.5.3) (2024.8.30)
# Requirement already satisfied: idna in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx>=0.27.0->chromadb==0.5.3) (3.8)
# Requirement already satisfied: anyio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx>=0.27.0->chromadb==0.5.3) (4.4.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.3) (0.14.0)
# Collecting oauthlib>=3.2.2
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.2.2)
# Collecting google-auth>=1.0.1
#   Using cached google_auth-2.34.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: sympy in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (1.13.2)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting flatbuffers
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting protobuf
#   Downloading protobuf-5.28.0-cp310-abi3-win_amd64.whl (431 kB)
#      ---------------------------------------- 0.0/431.5 kB ? eta -:--:--
#      ------------------------------------  430.1/431.5 kB 13.1 MB/s eta 0:00:01
#      -------------------------------------- 431.5/431.5 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (8.4.0)
# Collecting deprecated>=1.2.6
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Collecting googleapis-common-protos~=1.52
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Collecting opentelemetry-proto==1.27.0
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#      ---------------------------------------- 0.0/52.5 kB ? eta -:--:--
#      ---------------------------------------- 52.5/52.5 kB 2.6 MB/s eta 0:00:00
# Collecting protobuf
#   Using cached protobuf-4.25.4-cp310-abi3-win_amd64.whl (413 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#      ---------------------------------------- 0.0/149.7 kB ? eta -:--:--
#      -------------------------------------- 149.7/149.7 kB 4.5 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.48b0
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation==0.48b0
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (65.5.0)
# Collecting wrapt<2.0.0,>=1.0.0
#   Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Collecting asgiref~=3.0
#   Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic>=1.9->chromadb==0.5.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic>=1.9->chromadb==0.5.3) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests>=2.28->chromadb==0.5.3) (3.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from tokenizers>=0.13.2->chromadb==0.5.3) (0.24.6)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Using cached rich-13.8.0-py3-none-any.whl (241 kB)
# Collecting click>=8.0.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting httptools>=0.5.0
#   Using cached httptools-0.6.1-cp310-cp310-win_amd64.whl (58 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.24.0-cp310-none-win_amd64.whl (277 kB)
#      ---------------------------------------- 0.0/277.5 kB ? eta -:--:--
#      ------------------------------------- 277.5/277.5 kB 16.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting websockets>=10.4
#   Downloading websockets-13.0.1-cp310-cp310-win_amd64.whl (152 kB)
#      ---------------------------------------- 0.0/152.2 kB ? eta -:--:--
#      -------------------------------------- 152.2/152.2 kB 9.5 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: filelock in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.3) (3.20.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.18.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from anyio->httpx>=0.27.0->chromadb==0.5.3) (1.2.2)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.3) (1.3.0)
# Collecting pyreadline3
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: pyreadline3, pypika, monotonic, mmh3, flatbuffers, wrapt, websockets, websocket-client, tomli, shellingham, python-dotenv, pyproject_hooks, pyasn1, protobuf, overrides, opentelemetry-util-http, oauthlib, mdurl, importlib-resources, humanfriendly, httptools, grpcio, click, chroma-hnswlib, cachetools, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, googleapis-common-protos, deprecated, coloredlogs, build, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, fastapi, typer, opentelemetry-semantic-conventions, opentelemetry-instrumentation, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.1 cachetools-5.5.0 chroma-hnswlib-0.7.3 chromadb-0.5.3 click-8.1.7 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.112.2 flatbuffers-24.3.25 google-auth-2.34.0 googleapis-common-protos-1.65.0 grpcio-1.66.1 httptools-0.6.1 humanfriendly-10.0 importlib-resources-6.4.4 kubernetes-30.1.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.19.0 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.6.0 protobuf-4.25.4 pyasn1-0.6.0 pyasn1-modules-0.4.0 pypika-0.48.9 pyproject_hooks-1.1.0 pyreadline3-3.4.1 python-dotenv-1.0.1 requests-oauthlib-2.0.0 rich-13.8.0 rsa-4.9 shellingham-1.5.4 starlette-0.38.4 tomli-2.0.1 typer-0.12.5 uvicorn-0.30.6 watchfiles-0.24.0 websocket-client-1.8.0 websockets-13.0.1 wrapt-1.16.0
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pydantic==2.8.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (2.8.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic==2.8.2) (4.12.2)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic==2.8.2) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic==2.8.2) (0.7.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain-huggingface==0.0.3
#   Using cached langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-huggingface==0.0.3) (3.0.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-huggingface==0.0.3) (4.44.2)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-huggingface==0.0.3) (0.19.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-huggingface==0.0.3) (0.24.6)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-huggingface==0.0.3) (0.2.37)
# Requirement already satisfied: packaging>=20.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (4.12.2)
# Requirement already satisfied: requests in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2024.6.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (4.66.5)
# Requirement already satisfied: filelock in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.15.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.33)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (2.8.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.1.108)
# Requirement already satisfied: torch>=1.11.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (2.4.0)
# Requirement already satisfied: scikit-learn in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.5.1)
# Requirement already satisfied: numpy in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (10.4.0)
# Requirement already satisfied: scipy in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.14.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from transformers>=4.39.0->langchain-huggingface==0.0.3) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from transformers>=4.39.0->langchain-huggingface==0.0.3) (0.4.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (3.10.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.27.2)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2.2.2)
# Requirement already satisfied: jinja2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.1.4)
# Requirement already satisfied: networkx in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.3)
# Requirement already satisfied: sympy in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.13.2)
# Requirement already satisfied: colorama in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.4.2)
# Requirement already satisfied: sniffio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.0.5)
# Requirement already satisfied: anyio in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (4.4.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.2.2)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.0.3
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\jonnior_p\ibm_ai_hackathon\gust-ibm-ai-hackathon\final_porj\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA

from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import DecodingMethods
from langchain.llms import WatsonxLLM

# %%
load_dotenv()
# Out:
# True

# %%
# IBM Cloud 상의 watsonx SAS url은 provision된 region별로 정해져 있음. https://cloud.ibm.com/apidocs/watsonx-ai 참조.
project_id = os.getenv("PROJECT_ID", None)
wml_credentials = {
    "apikey": os.getenv("API_KEY", None),
    "url": 'https://us-south.ml.cloud.ibm.com'
}

# %%
def get_completion(prompt):
    
    params = {
        GenParams.DECODING_METHOD: DecodingMethods.GREEDY.value,
        GenParams.MIN_NEW_TOKENS: 1,
        GenParams.MAX_NEW_TOKENS: 3000,
        GenParams.STOP_SEQUENCES: ["\n\n\n"]
    }

    model_id =  'mistralai/mixtral-8x7b-instruct-v01' # 'meta-llama/llama-3-1-70b-instruct' # ModelTypes.LLAMA_2_70B_CHAT.value #
    watsonx_llama2_korean = WatsonxLLM(
        model_id=model_id,
        params=params,
        project_id=project_id,
        url=wml_credentials.get("url"),
        apikey=wml_credentials.get("apikey"),
    )
    response = watsonx_llama2_korean.generate(prompts=[prompt])

    return response

# %%
#사용자 입력받을 변수
age = 40
salary = "7000만원"
goal =  "10년 내에 5억 벌고 은퇴하고 싶습니다."
seed_money =  "2000만원"
investment_exp = "주식 투자 경험 있음"
investment_tendency = "공격투자형"
available_amount = "350만원"

investment_dict = {"안정형" : "예금이나 적금 수준의 수익률을 기대하며,투자원금에 손실이 발생하는 것을 원하지 않습니다. 원금 손실의 우려가 없는 상품에 투자하는 것이 바람직하며 CMA와 MMF, 적금, 정기예금이 좋습니다.",
   "안정추구형" : "투자원금의 손실위험은 최소화하고, 이자소득이나 배당소득 수준의 안정적인 투자를 목표로 합니다. 다만 수익을 위해 단기적인 손실을 수용할 수 있으며, 예·적금보다 높은 수익을 위해 자산 중의 일부를 변동성 높은 상품에 투자할 의향이 있습니다.채권형펀드*가 적당하며, 그중에서도 장기회사채펀드 등이 좋습니다.",
   "위험중립형" : "투자에는 그에 상응하는 투자위험이 있음을 충분히 인식하고 있으며, 예·적금보다높은 수익을 기대할 수 있다면 일정수준의 손실위험을 감수할 수 있습니다. 적립식펀드나 주가연동상품처럼 중위험 펀드로 분류되는 상품을 선택하는 것이 좋습니다.",
   "적극투자형" : "투자원금의 보전보다는 위험을 감내하더라도 높은 수준의 투자수익을 추구합니다.투자자금의 상당 부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다. 국내외 주식형펀드와 원금비보장형 주가연계증권(ELS) 등 고수익·고위험 상품에 투자할 수 있습니다.",
   "공격투자형" : "시장평균수익률을 훨씬 넘어서는 높은 수준의 투자수익을 추구하며, 이를 위해 자산가치의 변동에 따른 손실위험을 적극 수용할 수 있습니다. 투자자금 대부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다.주식 비중이 70% 이상인 고위험 펀드가 적당하고, 자산의 10% 정도는 직접투자(주식)도 고려해볼 만합니다."}
prompt1 = f"""
당신은 재무 설계 전문가입니다. 사용자로부터 다음 정보를 받으면, 해당 정보를 바탕으로 맞춤형 투자 및 저축 계획을 제공합니다.

맞춤형 투자 및 저축 계획 가이드:
1. 사용자의 나이, 연봉, 현재 저축액, 목표 금액, 목표 달성 기간, 투자 경험, 투자 성향을 입력받습니다.
2. 사용자가 목표 금액을 달성할 수 있도록 구체적인 투자 및 저축 계획을 제시합니다. 
3. 사용자의 투자 성향에 따라 저축 및 투자 방법을 다르게 추천합니다.{investment_dict}
4. 투자 및 저축 계획을 구체적으로 설명합니다.
5. 계획을 설명한 후 <|endoftext|>을 출력합니다.

예시1:
입력:
- 나이: 30세
- 연봉: 5000만원
- 목표: 5년 내에 1억 상당의 집을 사고 싶습니다.
- 현재 저축액: 1000만원
- 투자 경험: 없음
- 투자 성향: 안정형
- 월 저축 및 투자 가용금액: 150만원

출력:
안녕하세요, 30세의 사용자님. 5년 내에 집을 사고 싶다는 목표를 달성하기 위해 다음과 같은 투자 및 저축 계획을 제안드립니다.
예상수익률과 이자는 상품에 따라 상이합니다.

사용자님의 투자 성향은 안정형으로 투자 전략은 아래와 같습니다.
{investment_dict['안정형']}

1. **저축 계획**:
   - 매월 저축액: 월 저축 및 투자 가용금액 150만원의 70%인 105만원을 이자 3.5-4% 적금에 가입합니다.
   - 5년후 저축액: 105만원 X 60개월 + 적금이자 = 6300만원 +적금이자

2. **투자 계획**:
   - 초기 투자금: 원금 손실의 가능성이 없기 때문에 원금 모두
   - 투자 방법: 정기예금 및 CMA혼합 포트폴리오를 구성합니다. 정기예금 50%, CMA 50%로 분산 투자합니다.
   - 예상 수익률: 연평균 3.5% 가정
     - 근거: CMA평균 수익률 3.5%, 정기예금 최고 금리 평균 연 3.76%
   - 5년 후 예상 총 수익금(원금+수익): 원금 1000만원 + 수익(5 X 1000만원 X 0.035=175만원) = 약 1175만원

3. **총 자산 예상**:
   - 저축액: 약6300만원
   - 투자 수익: 약 1175만원
   - 총 자산: 저축액 + 투자수익 = 약 7475만원

이 계획을 통해 5년 내에 집을 사기 위한 자금을 준비할 수 있을 것입니다. 추가적인 상담이 필요하시면 언제든지 문의해 주세요.

예시2:
입력:
- 나이: 35세
- 연봉: 8000만원
- 목표: 10년 내에 10억 자산을 모으고 싶습니다.
- 현재 저축액: 5000만원
- 투자 경험: 주식, 부동산 투자 경험 있음
- 투자 성향: 공격투자형
- 월 저축 및 투자 가용금액: 500만원

출력:
안녕하세요, 35세의 사용자님. 10년 내에 10억 자산을 모으고 싶다는 목표를 달성하기 위해 다음과 같은 투자 및 저축 계획을 제안드립니다.
예상수익률과 이자는 상품에 따라 상이합니다.

사용자님의 투자 성향은 공격투자형으로 투자 전략은 아래와 같습니다.
{investment_dict['공격투자형']}

1. **저축 계획**:
   - 매월 저축액: 월 저축 및 투자 가용금액 500만원의 30%인 150만원을 현금성 자산(예: CMA)에 보유합니다.
   - 10년후 저축액: 150만원 X 120개월 + 이자 - 세금 = 1억 8000만원 + 이자 - 세금

2. **투자 계획**:
   - 초기 투자금: 5000만원 + 월 저축액 350만원을 공격적인 주식형 펀드와 개별 주식에 투자합니다.
   - 투자 방법: 주식 비중이 높은 고위험 펀드(70%)와 개별 주식(30%)에 투자합니다.
   - 예상 수익률: 연평균 8% 가정
     - 근거: 주식형 펀드와 개별 주식의 평균 수익률 8% 가정
   - 10년 후 예상 총 수익금(원금+수익): 원금 5000만원 + 수익(10 X 5000만원 X 0.08=4000만원) = 약 9000만원
   - 고위험 펀드와 개별 주식 투자는 원금 손실의 가능성이 높으므로 이 점에 유의하여 투자하세요

3. **총 자산 예상**:
   - 저축액: 약 1억 8000만원
   - 투자 수익: 약 9000만원
   - 총 자산: 저축액 + 투자수익 = 약 2억 7000만원

이 계획을 통해 10년 내에 10억 자산을 모으기 위한 첫 단계를 밟을 수 있을 것입니다. 추가적인 상담이 필요하시면 언제든지 문의해 주세요.


입력:
- 나이: {age}
- 연봉: {salary}
- 목표: {goal}
- 현재 저축액: {seed_money}
- 투자 경험: {investment_exp}
- 투자 성향: {investment_tendency}
- 월 저축 및 투자 가용금액: {available_amount}

출력:

"""
response = get_completion(prompt1)
print(response)
# Out:
# C:\Users\Jonnior_P\AppData\Local\Temp\ipykernel_20800\881342093.py:11: LangChainDeprecationWarning: The class `WatsonxLLM` was deprecated in LangChain 0.0.18 and will be removed in 0.3. An updated version of the class exists in the langchain-ibm package and should be used instead. To use it run `pip install -U langchain-ibm` and import as `from langchain_ibm import WatsonxLLM`.
#   watsonx_llama2_korean = WatsonxLLM(
# generations=[[Generation(text='안녕하세요, 40세의 사용자님. 10년 내에 5억 벌고 은퇴하고 싶다는 목표를 달성하기 위해 다음과 같은 투자 및 저축 계획을 제안드립니다.\n예상수익률과 이자는 상품에 따라 상이합니다.\n\n사용자님의 투자 성향은 공격투자형으로 투자 전략은 아래와 같습니다.\n시장평균수익률을 훨씬 넘어서는 높은 수준의 투자수익을 추구하며, 이를 위해 자산가치의 변동에 따른 손실위험을 적극 수용할 수 있습니다. 투자자금 대부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다.주식 비중이 70% 이상인 고위험 펀드가 적당하고, 자산의 10% 정도는 직접투자(주식)도 고려해볼 만합니다.\n\n1. **저축 계획**:\n   - 매월 저축액: 월 저축 및 투자 가용금액 350만원의 30%인 105만원을 현금성 자산(예: CMA)에 보유합니다.\n   - 10년후 저축액: 105만원 X 120개월 + 이자 = 1억 2600만원 + 이자\n\n2. **투자 계획**:\n   - 초기 투자금: 2000만원 + 월 저축액 245만원을 공격적인 주식형 펀드와 개별 주식에 투자합니다.\n   - 투자 방법: 주식 비중이 높은 고위험 펀드(70%)와 개별 주식(30%)에 투자합니다.\n   - 예상 수익률: 연평균 8% 가정\n     - 근거: 주식형 펀드와 개별 주식의 평균 수익률 8% 가정\n   - 10년 후 예상 총 수익금(원금+수익): 원금 2000만원 + 수익(10 X 245만원 X 0.08=1960만원) = 약 4960만원\n\n3. **총 자산 예상**:\n   - 저축액: 약 1억 2600만원\n   - 투자 수익: 약 4960만원\n   - 총 자산: 저축액 + 투자수익 = 약 6460만원\n\n이 계획을 통해 10년 내에 5억을 벌고 은퇴하기 위한 첫 단계를 밟을 수 있을 것입니다. 추가적인 상담이 필요하시면 언제든지 문의해 주세요.\n\n<|endoftext|>', generation_info={'finish_reason': 'eos_token'})]] llm_output={'token_usage': {'generated_token_count': 1025, 'input_token_count': 3642}, 'model_id': 'mistralai/mixtral-8x7b-instruct-v01', 'deployment_id': ''} run=[RunInfo(run_id=UUID('5bd7ca6a-3e5f-47a6-b2ed-aa82c547d0f7'))]

# %%
print(response.generations[0][0].text)
# Out:
# 안녕하세요, 40세의 사용자님. 10년 내에 5억 벌고 은퇴하고 싶다는 목표를 달성하기 위해 다음과 같은 투자 및 저축 계획을 제안드립니다.
# 예상수익률과 이자는 상품에 따라 상이합니다.
#
# 사용자님의 투자 성향은 공격투자형으로 투자 전략은 아래와 같습니다.
# 시장평균수익률을 훨씬 넘어서는 높은 수준의 투자수익을 추구하며, 이를 위해 자산가치의 변동에 따른 손실위험을 적극 수용할 수 있습니다. 투자자금 대부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다.주식 비중이 70% 이상인 고위험 펀드가 적당하고, 자산의 10% 정도는 직접투자(주식)도 고려해볼 만합니다.
#
# 1. **저축 계획**:
#    - 매월 저축액: 월 저축 및 투자 가용금액 350만원의 30%인 105만원을 현금성 자산(예: CMA)에 보유합니다.
#    - 10년후 저축액: 105만원 X 120개월 + 이자 = 1억 2600만원 + 이자
#
# 2. **투자 계획**:
#    - 초기 투자금: 2000만원 + 월 저축액 245만원을 공격적인 주식형 펀드와 개별 주식에 투자합니다.
#    - 투자 방법: 주식 비중이 높은 고위험 펀드(70%)와 개별 주식(30%)에 투자합니다.
#    - 예상 수익률: 연평균 8% 가정
#      - 근거: 주식형 펀드와 개별 주식의 평균 수익률 8% 가정
#    - 10년 후 예상 총 수익금(원금+수익): 원금 2000만원 + 수익(10 X 245만원 X 0.08=1960만원) = 약 4960만원
#
# 3. **총 자산 예상**:
#    - 저축액: 약 1억 2600만원
#    - 투자 수익: 약 4960만원
#    - 총 자산: 저축액 + 투자수익 = 약 6460만원
#
# 이 계획을 통해 10년 내에 5억을 벌고 은퇴하기 위한 첫 단계를 밟을 수 있을 것입니다. 추가적인 상담이 필요하시면 언제든지 문의해 주세요.
#
# <|endoftext|>

# %%
#사용자 입력받을 변수
age = 40
salary = "7000만원"
goal =  "10년 내에 3억 벌고 은퇴하고 싶습니다."
seed_money =  "2000만원"
investment_exp = "주식 투자 경험 있음"
investment_tendency = "안정형"
available_amount = "350만원"

investment_dict = {"안정형" : "예금이나 적금 수준의 수익률을 기대하며,투자원금에 손실이 발생하는 것을 원하지 않습니다. 원금 손실의 우려가 없는 상품에 투자하는 것이 바람직하며 CMA와 MMF, 적금, 정기예금이 좋습니다.",
   "안정추구형" : "투자원금의 손실위험은 최소화하고, 이자소득이나 배당소득 수준의 안정적인 투자를 목표로 합니다. 다만 수익을 위해 단기적인 손실을 수용할 수 있으며, 예·적금보다 높은 수익을 위해 자산 중의 일부를 변동성 높은 상품에 투자할 의향이 있습니다.채권형펀드*가 적당하며, 그중에서도 장기회사채펀드 등이 좋습니다.",
   "위험중립형" : "투자에는 그에 상응하는 투자위험이 있음을 충분히 인식하고 있으며, 예·적금보다높은 수익을 기대할 수 있다면 일정수준의 손실위험을 감수할 수 있습니다. 적립식펀드*나 주가연동상품처럼 중위험 펀드로 분류되는 상품을 선택하는 것이 좋습니다.",
   "적극투자형" : "투자원금의 보전보다는 위험을 감내하더라도 높은 수준의 투자수익을 추구합니다.투자자금의 상당 부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다. 국내외 주식형펀드와 원금비보장형 주가연계증권(ELS) 등 고수익·고위험 상품에 투자할 수 있습니다.",
   "공격투자형" : "시장평균수익률을 훨씬 넘어서는 높은 수준의 투자수익을 추구하며, 이를 위해 자산가치의 변동에 따른 손실위험을 적극 수용할 수 있습니다. 투자자금 대부분을 주식, 주식형펀드 또는 파생상품 등의 위험자산에 투자할 의향이 있습니다.주식 비중이 70% 이상인 고위험 펀드가 적당하고, 자산의 10% 정도는 직접투자(주식)도 고려해볼 만합니다."}
prompt2 = f"""
당신은 재무 설계 전문가입니다. 사용자로부터 다음 정보를 받으면, 해당 정보를 바탕으로 맞춤형 투자 및 저축 계획을 제공합니다:
1. 사용자의 나이, 연봉, 현재 저축액, 목표 금액, 목표 달성 기간, 투자 경험, 투자 성향을 입력받습니다.
2. 사용자가 목표 금액을 달성할 수 있도록 구체적인 투자 및 저축 계획을 제시합니다. 
3. 사용자의 투자 성향에 따라 저축 및 투자 방법을 다르게 추천합니다.{investment_dict}
4. 투자 및 저축 계획을 구체적으로 설명합니다.

예시:
입력:
- 나이: {age}
- 연봉: {salary}
- 목표: {goal}
- 현재 저축액: {seed_money}
- 투자 경험: {investment_exp}
- 투자 성향: {investment_tendency}
- 월 저축 및 투자 가용금액: {available_amount}

출력:
안녕하세요, 30세의 사용자님. 5년 내에 집을 사고 싶다는 목표를 달성하기 위해 다음과 같은 투자 및 저축 계획을 제안드립니다.
예상수익률과 이자는 상품에 따라 상이합니다.

사용자님의 투자 성향은 안정형으로 투자 전략은 아래와 같습니다.
{investment_dict['안정형']}

1. 사용자 나이와 목표 달성 기간을 고려할 때, 목표 금액을 달성하기 위해 매월 필요한 저축액과 투자액을 계산합니다.
2. 중립적 투자 성향에 맞게, 저축과 투자를 어떻게 분배할지 구체적으로 설명합니다.
3. 앞에서 제시한 계획에 따라 진행했을 때의 최종 자산을 출력합니다.
"""
response = get_completion(prompt2)
print(response)
# Out:
# C:\Users\Jonnior_P\AppData\Local\Temp\ipykernel_24680\4059216936.py:11: LangChainDeprecationWarning: The class `WatsonxLLM` was deprecated in LangChain 0.0.18 and will be removed in 0.3. An updated version of the class exists in the langchain-ibm package and should be used instead. To use it run `pip install -U langchain-ibm` and import as `from langchain_ibm import WatsonxLLM`.
#   watsonx_llama2_korean = WatsonxLLM(
# generations=[[Generation(text='- 매월 저축액: 200만원\n- 매월 투자액: 150만원\n\n3. 매월 저축액과 투자액을 어떤 상품에 적용할지 구체적으로 설명합니다.\n\n- 매월 저축액: 200만원\n  - 적금: 100만원\n  - 정기예금: 100만원\n\n- 매월 투자액: 150만원\n  - CMA: 50만원\n  - MMF: 100만원\n\n4. 예상 수익률과 이자를 구체적으로 설명합니다.\n\n- 적금: 1.5%\n- 정기예금: 2%\n- CMA: 2.5%\n- MMF: 3%\n\n5. 예상 목표 달성 기간과 최종 예상 수익률을 구체적으로 설명합니다.\n\n- 예상 목표 달성 기간: 5년\n- 최종 예상 수익률: 2.5%\n\n6. 추가 조언을 구체적으로 설명합니다.\n\n- 추가 조언: 매월 저축액과 투자액을 철저히 지키고, 시장 변동에 따른 투자 위험을 최소화하기 위해 정기적으로 투자 현황을 살펴보고 조정하는 것이 좋습니다.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n ...

# %%
import textwrap

def format_response(response):
    """
    주어진 텍스트 응답을 보기 좋게 포맷하여 반환합니다.
    """
    # 텍스트를 800자로 제한하여 줄바꿈을 적용
    formatted_response = textwrap.fill(response, width=800, replace_whitespace=False, 
                                       initial_indent='', subsequent_indent='    ')
    return formatted_response

response = """
안녕하세요. 40세의 사용자님! 10년 내에 100억을 벌고 은퇴하기 위한 목표를 달성하기 위해 투자 및 저축 계획을 2가지 제안드립니다.

1. **안정적인 투자 계획**:
   - **저축 계획**:
     - 매월 저축액: 연봉의 20%인 "140만원"을 목표로 합니다.
     - 10년 동안 저축액: 약 16800만원

   - **투자 계획**:
     - 초기 투자금: 현재 저축액 2000만원 중 1000만원을 투자합니다.
     - 투자 방법: 주식과 채권 혼합 포트폴리오(주식 40%, 채권 60%)를 구성합니다.
     - 예상 수익률: 연평균 4% 가정
       - **근거**: 과거 10년간 주식 시장의 연평균 수익률은 약 8%이며, 채권의 연평균 수익률은 약 5%입니다. 주식과 채권의 혼합 포트폴리오로 안정성을 높이기 위해 4%의 예상 수익률을 설정했습니다.
     - 10년 후 예상 투자 수익: 약 1680만원

   - **총 자산 예상**:
     - 저축액: 16800만원
     - 투자 수익: 1680만원
     - 총 자산: 약 18480만원

2. **위험한 투자 계획**:
   - **저축 계획**:
     - 매월 저축액: 연봉의 20%인 "140만원"을 목표로 합니다.
     - 10년 동안 저축액: 약 16800만원

   - **투자 계획**:
     - 초기 투자금: 현재 저축액 2000만원 중 1000만원을 투자합니다.
     - 투자 방법: 고위험 주식 포트폴리오(주식 100%)를 구성합니다.
     - 예상 수익률: 연평균 10% 가정
       - **근거**: 주식 시장의 변동성이 크지만, 적극적인 투자 전략과 시장 분석을 통해 높은 수익률을 기대할 수 있습니다. 과거 고위험 주식 포트폴리오의 연평균 수익률은 약 10%에 달했습니다.
     - 10년 후 예상 투자 수익: 약 3560만원

   - **총 자산 예상**:
     - 저축액: 16800만원
     - 투자 수익: 3560만원
     - 총 자산: 약 20360만원

이 계획을 통해 10년 내에 100억을 벌고 은퇴하기 위한 자금을 준비할 수 있을 것입니다. 두 계획 중 한가지를 선택해주시면 그에 맞는 주식 상품을 추천해드리겠습니다!
"""

# 포맷팅된 결과 출력
formatted_response = format_response(response)
print(formatted_response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 13
#      10     return formatted_response
#      12 # 포맷팅된 결과 출력
# ---> 13 formatted_response = format_response(response)
#      14 print(formatted_response)
#
# Cell In[7], line 8, in format_response(response)
#       4 """
#       5 주어진 텍스트 응답을 보기 좋게 포맷하여 반환합니다.
#       6 """
#       7 # 텍스트를 800자로 제한하여 줄바꿈을 적용
# ----> 8 formatted_response = textwrap.fill(response, width=800, replace_whitespace=False,
#       9                                    initial_indent='', subsequent_indent='    ')
#      10 return formatted_response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\textwrap.py:399, in fill(text, width, **kwargs)
#     390 """Fill a single paragraph of text, returning a new string.
#     391
#     392 Reformat the single paragraph in 'text' to fit in lines of no more
#    (...)
#     396 available keyword args to customize wrapping behaviour.
#     397 """
#     398 w = TextWrapper(width=width, **kwargs)
# --> 399 return w.fill(text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\textwrap.py:371, in TextWrapper.fill(self, text)
#     364 def fill(self, text):
#     365     """fill(text : string) -> string
#     366
#     367     Reformat the single paragraph in 'text' to fit in lines of no
#     368     more than 'self.width' columns, and return a new string
#     369     containing the entire wrapped paragraph.
#     370     """
# --> 371     return "\n".join(self.wrap(text))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\textwrap.py:359, in TextWrapper.wrap(self, text)
#     350 def wrap(self, text):
#     351     """wrap(text : string) -> [string]
#     352
#     353     Reformat the single paragraph in 'text' so it fits in lines of
#    (...)
#     357     converted to space.
#     358     """
# --> 359     chunks = self._split_chunks(text)
#     360     if self.fix_sentence_endings:
#     361         self._fix_sentence_endings(chunks)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\textwrap.py:345, in TextWrapper._split_chunks(self, text)
#     344 def _split_chunks(self, text):
# --> 345     text = self._munge_whitespace(text)
#     346     return self._split(text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\textwrap.py:154, in TextWrapper._munge_whitespace(self, text)
#     147 """_munge_whitespace(text : string) -> string
#     148
#     149 Munge whitespace in text: expand tabs and convert all other
#     150 whitespace characters to spaces.  Eg. " foo\\tbar\\n\\nbaz"
#     151 becomes " foo    bar  baz".
#     152 """
#     153 if self.expand_tabs:
# --> 154     text = text.expandtabs(self.tabsize)
#     155 if self.replace_whitespace:
#     156     text = text.translate(self.unicode_whitespace_trans)
#
# AttributeError: 'LLMResult' object has no attribute 'expandtabs'
